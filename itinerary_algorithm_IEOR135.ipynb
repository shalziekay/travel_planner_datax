# %% [markdown]
# # Itinerary Algorithm
#
# Below are the functions modularized to add to the itinerary and create the order of attractions based on user preferences. The algorithm functions below only consider attractions at the moment, restuarant data will need to be added in.
#
# Libraries used:
# - numpy
# - pandas
# - matplotlib
# - sklearn
# - collections
# - datetime
# - math
# - geopy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from collections import Counter
from datetime import date
import math
import geopy
from geopy.distance import vincenty

# %%
def attraction_clustering(start_date, end_date, city_name, attractions_df):
    """
    Inputs: start date, end date, city name user is traveling to, and the attractions dataframe
    Returns the filtered data with the clusters in a separate column based on KMeans
    Start and end date should already be in date(2020, 5, 15) type of format for this function to work
    """
    num_days = end_date - start_date
    num_days = num_days.days
    print("Number of days: ", num_days)
    print("City: ", city_name)

    filtered_data = attractions_df[attractions_df["City"] == city_name]
    index_names = filtered_data[filtered_data['Address'] == "No Address Found"].index
    filtered_data.drop(index_names, inplace=True)

    X = filtered_data.loc[:,['Latitude','Longitude']]

    kmeans = KMeans(n_clusters=num_days, random_state=0, max_iter = 1000).fit(X)
    id_label=kmeans.labels_

    filtered_data["cluster"] = kmeans.labels_
    return filtered_data

# %%
def get_start_per_cluster(df):
    """
    Take in the dataframe that is the result of attraction clustering (each attraction in a cluster)
    Returns a dataframe that has num_days number of rows (or one row per cluster) 
    based on the top ranked attraction in the cluster
    """
    idx = df.groupby(["cluster"])["Rank"].transform(min) == df['Rank'] 
    starting_attractions = df[idx]
    return starting_attractions

# %%
# anjali's function
def distances(starting_lat, starting_long, dataframe):
    """
    Function written by Anjali which gets the distances from the input starting lat and long to different places
    The dataframe is sorted based on distance from nearest to furthest
    """
    dataframe["Latitude"] = [-1 if lat == "No Address Found" else pd.to_numeric(lat) 
                             for lat in dataframe["Latitude"]]
    dataframe["Longitude"] = [-1 if long == "No Address Found" else pd.to_numeric(long)
                              for long in dataframe["Longitude"]]
    
    coords_1 = (starting_lat, starting_long)
    coords_2 = [(dataframe["Latitude"][i], dataframe["Longitude"][i]) 
                for i in range(len(dataframe["Latitude"]))]
    dists = [-1 if (math.isnan(coords_2[i][0]) & math.isnan(coords_2[i][1])) 
             else (vincenty(coords_1, coords_2[i]).miles)
             for i in range(len(coords_2))]
    dataframe_copy = dataframe 
    dataframe_copy['distance_from_start'] = dists
    dataframe_copy = dataframe_copy.sort_values(by='distance_from_start', ascending=True)
    return dataframe_copy

# %%
def rank_user_pref(user_pref_list, df):
    """
    Take in the df that has already been ranked by distance
    Takes into account the user preferences and adds a flag based on if an attraction follows with the user preference list or not
    The dataframe is then sorted by user preferences and then distances, within a cluster (return this)
    """

    preferences_mapping = {
    "Museums" : ["Museums"],
    "Famous Sites": ["Nature & Parks", "Sights & Landmarks"],
    "History": ["Transportation", "Events"],
    "Thrill-seeking adventures": ["Concerts & Shows", "Casinos & Gambling", "Water & Amusement Parks"],
    "Food" : ["Food & Drink"],
    "Shopping" : ["Shopping"],
    }
    
    if "A bit of everything" in user_pref_list:
        return df

    elif len(user_pref_list) != 0:
        # to get all the preferences corresponding to Type of Attraction
        top_prefs = []
        for p in user_pref_list:
            top_prefs += preferences_mapping[p]
            
        # put a flag 1 if attraction is something in user preferences, 0 otherwise
        df["user_pref_flag"] = df["Type"].apply(lambda x: 0 if x in top_prefs else 1)
        
        # sort by cluster, top_prefs (desc), dist
        df = df.sort_values(by=['cluster', 'user_pref_flag', 'Distance Ranking Order'])
        return df
      
    else:
        return df

# %%
# inputs we have: start and end date, what city user wants to go 
# random start, end dates and city name for testing purposes
start_date = date(2020, 5, 15)
end_date = date(2020, 5, 18)
city_name = "San Francisco"
user_preferences = ['Food', 'Shopping', 'Museums']
attractions = pd.read_csv("top_thirty_attraction_tripadvisor_sf_no_la.csv")

clustered_df = attraction_clustering(start_date, end_date, city_name, attractions)
start_att_df = get_start_per_cluster(clustered_df)
# Out:
# Number of days:  3
# City:  San Francisco
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dist_columns = list(clustered_df.columns) + ["Distance Ranking Order"]
cluster_distance_df = pd.DataFrame(data=[], columns=dist_columns)

for index, row in start_att_df.iterrows(): 
    start_lat = row["Latitude"]
    start_long = row["Longitude"]
    cluster_df = clustered_df[clustered_df["cluster"] == row["cluster"]].reset_index()
    end_df = distances(start_lat, start_long, cluster_df)
    distance_ranking_order = [i for i in range(1, end_df.shape[0] + 1)]
    end_df["Distance Ranking Order"] = distance_ranking_order
    cluster_distance_df = cluster_distance_df.append(end_df)
# Out:
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
#   from ipykernel import kernelapp as app

# %% [markdown]
# The result is a dataframe that has all the original attraction information but also includes what cluster the attraction is in based on the KMeans clustering done above, and the order the sites should be visited in based on looking at the top attraction in each cluster and ranking based on nearest distance.

# %%
cluster_distance_df
# Out:
#                                               Address  \
# 0   Alcatraz Island, Parade Ground, San Francisco,...
# 11  Musée Mécanique, Fishermans Wharf, Russian Hil...
# 12  Fishermans Wharf, Russian Hill, San Francisco,...
# 10  Pier 39, North Beach, San Francisco, San Franc...
# 4   Lombard Street, Russian Hill, San Francisco, S...
# 7   Coit Tower, Telegraph Hill Boulevard, Telegrap...
# 2   Exploratorium, Herb Caen Way, Northeast Waterf...
# 9   Cable Car Museum, 1201, Mason Street, Nob Hill...
# 3           1 Ferry Building, San Francisco, CA 94111
# 5   Museum of Ice Cream, 1, Grant Avenue, Union Sq...
# 6                 151 3rd St, San Francisco, CA 94103
# 8   San Francisco, San Francisco City and County, ...
# 1   Oracle Park, 24, Willie Mays Plaza, South Beac...
# 13  Mission Dolores Park, Liberty Street Historic ...
# 0   Golden Gate Bridge, San Francisco, San Francis...
# 4   Presidio of San Francisco, Presidio Terrace, S...
# 2   Walt Disney Family Museum, 104, Montgomery Str...
# 1   Palace of Fine Arts, 3601, Lyon St, San Franci...
# 3                                   Tiburon, CA 94920
# 0   Golden Gate Park, Richmond District, San Franc...
# 7   Japanese Tea Garden, 75, Hagiwara Tea Garden D...
# 5   San Francisco Botanical Garden, 1199, 9th Aven...
# 6   De Young Museum, 50, Hagiwara Tea Garden Drive...
# 2   California Academy of Sciences, 55, Music Conc...
# 9                   16th Ave, San Francisco, CA 94122
# 4   Legion of Honor, 100, 34th Avenue, Seacliff, S...
# 8   Baker Beach, Bowley Street, Seacliff, San Fran...
# 3   Lands End, San Francisco, San Francisco City a...
# 1   Twin Peaks, Christmas Tree Point Road, Cole Va...
#
#                                 Attraction Name           City  \
# 0                               Alcatraz Island  San Francisco
# 11                              Musee Mecanique  San Francisco
# 12                            Fisherman's Wharf  San Francisco
# 10                                      Pier 39  San Francisco
# 4                                Lombard Street  San Francisco
# 7                                    Coit Tower  San Francisco
# 2                                 Exploratorium  San Francisco
# 9                              Cable Car Museum  San Francisco
# 3                    Ferry Building Marketplace  San Francisco
# 5                           Museum of Ice Cream  San Francisco
# 6   San Francisco Museum of Modern Art (SFMOMA)  San Francisco
# 8                             San Francisco Bay  San Francisco
# 1                                   Oracle Park  San Francisco
# 13                         Mission Dolores Park  San Francisco
# 0                            Golden Gate Bridge  San Francisco
# 4                     Presidio of San Francisco  San Francisco
# 2                     Walt Disney Family Museum  San Francisco
# 1                   Palace of Fine Arts Theatre  San Francisco
# 3                       Angel Island State Park  San Francisco
# 0                              Golden Gate Park  San Francisco
# 7                           Japanese Tea Garden  San Francisco
# 5                San Francisco Botanical Garden  San Francisco
# 6                               de Young Museum  San Francisco
# 2                California Academy of Sciences  San Francisco
# 9                         16 Avenue Tiled Steps  San Francisco
# 4                               Legion of Honor  San Francisco
# 8                                   Baker Beach  San Francisco
# 3                                     Lands End  San Francisco
# 1                                    Twin Peaks  San Francisco
#
#    Distance Ranking Order   Latitude  \
# 0                       1  37.826721
# 11                      2  37.809449
# 12                      3  37.809167
# 10                      4  37.809785
# 4                       5  37.802076
# 7                       6  37.802379
# 2                       7  37.800906
# 9                       8  37.794810
# 3                       9  37.795800
# 5                      10  37.787008
# 6                      11  37.785700
# 8                      12  37.779026
# 1                      13  37.778612
# 13                     14  37.759720
# 0                       1  37.830321
# 4                       2  37.799912
# 2                       3  37.801363
# 1                       4  37.802000
# 3                       5  37.860900
# 0                       1  37.769368
# 7                       2  37.770333
# 5                       3  37.767366
# 6                       4  37.771480
# 2                       5  37.769825
# 9                       6  37.756300
# 4                       7  37.784558
# 8                       8  37.793109
# 3                       9  37.783887
# 1                      10  37.754640
#
#                            Link to Attraction Reviews   Longitude  \
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.422759
# 11  www.tripadvisor.com/Attraction_Review-g60713-d... -122.416283
# 12  www.tripadvisor.com/Attraction_Review-g60713-d... -122.416599
# 10  www.tripadvisor.com/Attraction_Review-g60713-d... -122.410266
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.418809
# 7   www.tripadvisor.com/Attraction_Review-g60713-d... -122.405834
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.398523
# 9   www.tripadvisor.com/Attraction_Review-g60713-d... -122.411863
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.393800
# 5   www.tripadvisor.com/Attraction_Review-g60713-d... -122.405166
# 6   www.tripadvisor.com/Attraction_Review-g60713-d... -122.401100
# 8   www.tripadvisor.com/Attraction_Review-g60713-d... -122.419906
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.390267
# 13  www.tripadvisor.com/Attraction_Review-g60713-d... -122.427132
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.479750
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.463829
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.458721
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.448600
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.432600
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.482184
# 7   www.tripadvisor.com/Attraction_Review-g60713-d... -122.470089
# 5   www.tripadvisor.com/Attraction_Review-g60713-d... -122.469608
# 6   www.tripadvisor.com/Attraction_Review-g60713-d... -122.469128
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.466087
# 9   www.tripadvisor.com/Attraction_Review-g60713-d... -122.473200
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.500955
# 8   www.tripadvisor.com/Attraction_Review-g60713-d... -122.483842
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.506829
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.446480
#
#    Number of Reviews     Price Rank                Type cluster  \
# 0     55,267 reviews   $105.00    1      Nature & Parks       0
# 11     2,869 reviews  No Price   23             Museums       0
# 12    19,301 reviews    $20.00   27  Sights & Landmarks       0
# 10    22,474 reviews  No Price   20  Sights & Landmarks       0
# 4     18,111 reviews  No Price   13  Sights & Landmarks       0
# 7      4,477 reviews  No Price   16  Sights & Landmarks       0
# 2      3,491 reviews    $19.95    7             Museums       0
# 9      3,700 reviews  No Price   19             Museums       0
# 3      7,358 reviews  No Price   12            Shopping       0
# 5      1,591 reviews  No Price   14             Museums       0
# 6      2,036 reviews    $25.00   15             Museums       0
# 8      7,319 reviews  No Price   17      Nature & Parks       0
# 1      7,082 reviews  No Price    3  Sights & Landmarks       0
# 13       870 reviews  No Price   30      Nature & Parks       0
# 0     49,248 reviews  No Price    2  Sights & Landmarks       2
# 4      1,854 reviews  No Price   26      Nature & Parks       2
# 2      2,756 reviews    $25.00    9             Museums       2
# 1      4,414 reviews  No Price    4    Concerts & Shows       2
# 3        974 reviews  No Price   25      Nature & Parks       2
# 0      9,502 reviews    $15.00    5      Nature & Parks       1
# 7      3,298 reviews  No Price   24      Nature & Parks       1
# 5        908 reviews     $9.00   21      Nature & Parks       1
# 6      2,139 reviews    $15.00   22             Museums       1
# 2      5,953 reviews    $15.00    8             Museums       1
# 9        635 reviews  No Price   29  Sights & Landmarks       1
# 4      1,932 reviews    $15.00   18             Museums       1
# 8        941 reviews  No Price   28      Nature & Parks       1
# 3      2,822 reviews  No Price   10      Nature & Parks       1
# 1      6,378 reviews  No Price    6  Sights & Landmarks       1
#
#     distance_from_start  index
# 0          0.000000e+00    0.0
# 11         1.242812e+00   22.0
# 12         1.256720e+00   26.0
# 10         1.353330e+00   19.0
# 4          1.713420e+00   12.0
# 7          1.917285e+00   15.0
# 2          2.219988e+00    6.0
# 9          2.280188e+00   18.0
# 3          2.656803e+00   11.0
# 5          2.903211e+00   13.0
# 6          3.067366e+00   14.0
# 8          3.293127e+00   16.0
# 1          3.764367e+00    2.0
# 13         4.627095e+00   29.0
# 0          0.000000e+00    1.0
# 4          2.270942e+00   25.0
# 2          2.304918e+00    8.0
# 1          2.592252e+00    3.0
# 3          3.331236e+00   24.0
# 0          4.390790e-13    4.0
# 7          6.654703e-01   23.0
# 5          7.021737e-01   20.0
# 6          7.294732e-01   21.0
# 2          8.818229e-01    7.0
# 9          1.026757e+00   28.0
# 4          1.467435e+00   17.0
# 8          1.639878e+00   27.0
# 3          1.680131e+00    9.0
# 1          2.203012e+00    5.0

# %%
user_pref_and_clustered_distance = rank_user_pref(user_preferences, cluster_distance_df)
user_pref_and_clustered_distance
# Out:
#                                               Address  \
# 11  Musée Mécanique, Fishermans Wharf, Russian Hil...
# 2   Exploratorium, Herb Caen Way, Northeast Waterf...
# 9   Cable Car Museum, 1201, Mason Street, Nob Hill...
# 3           1 Ferry Building, San Francisco, CA 94111
# 5   Museum of Ice Cream, 1, Grant Avenue, Union Sq...
# 6                 151 3rd St, San Francisco, CA 94103
# 0   Alcatraz Island, Parade Ground, San Francisco,...
# 12  Fishermans Wharf, Russian Hill, San Francisco,...
# 10  Pier 39, North Beach, San Francisco, San Franc...
# 4   Lombard Street, Russian Hill, San Francisco, S...
# 7   Coit Tower, Telegraph Hill Boulevard, Telegrap...
# 8   San Francisco, San Francisco City and County, ...
# 1   Oracle Park, 24, Willie Mays Plaza, South Beac...
# 13  Mission Dolores Park, Liberty Street Historic ...
# 6   De Young Museum, 50, Hagiwara Tea Garden Drive...
# 2   California Academy of Sciences, 55, Music Conc...
# 4   Legion of Honor, 100, 34th Avenue, Seacliff, S...
# 0   Golden Gate Park, Richmond District, San Franc...
# 7   Japanese Tea Garden, 75, Hagiwara Tea Garden D...
# 5   San Francisco Botanical Garden, 1199, 9th Aven...
# 9                   16th Ave, San Francisco, CA 94122
# 8   Baker Beach, Bowley Street, Seacliff, San Fran...
# 3   Lands End, San Francisco, San Francisco City a...
# 1   Twin Peaks, Christmas Tree Point Road, Cole Va...
# 2   Walt Disney Family Museum, 104, Montgomery Str...
# 0   Golden Gate Bridge, San Francisco, San Francis...
# 4   Presidio of San Francisco, Presidio Terrace, S...
# 1   Palace of Fine Arts, 3601, Lyon St, San Franci...
# 3                                   Tiburon, CA 94920
#
#                                 Attraction Name           City  \
# 11                              Musee Mecanique  San Francisco
# 2                                 Exploratorium  San Francisco
# 9                              Cable Car Museum  San Francisco
# 3                    Ferry Building Marketplace  San Francisco
# 5                           Museum of Ice Cream  San Francisco
# 6   San Francisco Museum of Modern Art (SFMOMA)  San Francisco
# 0                               Alcatraz Island  San Francisco
# 12                            Fisherman's Wharf  San Francisco
# 10                                      Pier 39  San Francisco
# 4                                Lombard Street  San Francisco
# 7                                    Coit Tower  San Francisco
# 8                             San Francisco Bay  San Francisco
# 1                                   Oracle Park  San Francisco
# 13                         Mission Dolores Park  San Francisco
# 6                               de Young Museum  San Francisco
# 2                California Academy of Sciences  San Francisco
# 4                               Legion of Honor  San Francisco
# 0                              Golden Gate Park  San Francisco
# 7                           Japanese Tea Garden  San Francisco
# 5                San Francisco Botanical Garden  San Francisco
# 9                         16 Avenue Tiled Steps  San Francisco
# 8                                   Baker Beach  San Francisco
# 3                                     Lands End  San Francisco
# 1                                    Twin Peaks  San Francisco
# 2                     Walt Disney Family Museum  San Francisco
# 0                            Golden Gate Bridge  San Francisco
# 4                     Presidio of San Francisco  San Francisco
# 1                   Palace of Fine Arts Theatre  San Francisco
# 3                       Angel Island State Park  San Francisco
#
#    Distance Ranking Order   Latitude  \
# 11                      2  37.809449
# 2                       7  37.800906
# 9                       8  37.794810
# 3                       9  37.795800
# 5                      10  37.787008
# 6                      11  37.785700
# 0                       1  37.826721
# 12                      3  37.809167
# 10                      4  37.809785
# 4                       5  37.802076
# 7                       6  37.802379
# 8                      12  37.779026
# 1                      13  37.778612
# 13                     14  37.759720
# 6                       4  37.771480
# 2                       5  37.769825
# 4                       7  37.784558
# 0                       1  37.769368
# 7                       2  37.770333
# 5                       3  37.767366
# 9                       6  37.756300
# 8                       8  37.793109
# 3                       9  37.783887
# 1                      10  37.754640
# 2                       3  37.801363
# 0                       1  37.830321
# 4                       2  37.799912
# 1                       4  37.802000
# 3                       5  37.860900
#
#                            Link to Attraction Reviews   Longitude  \
# 11  www.tripadvisor.com/Attraction_Review-g60713-d... -122.416283
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.398523
# 9   www.tripadvisor.com/Attraction_Review-g60713-d... -122.411863
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.393800
# 5   www.tripadvisor.com/Attraction_Review-g60713-d... -122.405166
# 6   www.tripadvisor.com/Attraction_Review-g60713-d... -122.401100
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.422759
# 12  www.tripadvisor.com/Attraction_Review-g60713-d... -122.416599
# 10  www.tripadvisor.com/Attraction_Review-g60713-d... -122.410266
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.418809
# 7   www.tripadvisor.com/Attraction_Review-g60713-d... -122.405834
# 8   www.tripadvisor.com/Attraction_Review-g60713-d... -122.419906
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.390267
# 13  www.tripadvisor.com/Attraction_Review-g60713-d... -122.427132
# 6   www.tripadvisor.com/Attraction_Review-g60713-d... -122.469128
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.466087
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.500955
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.482184
# 7   www.tripadvisor.com/Attraction_Review-g60713-d... -122.470089
# 5   www.tripadvisor.com/Attraction_Review-g60713-d... -122.469608
# 9   www.tripadvisor.com/Attraction_Review-g60713-d... -122.473200
# 8   www.tripadvisor.com/Attraction_Review-g60713-d... -122.483842
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.506829
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.446480
# 2   www.tripadvisor.com/Attraction_Review-g60713-d... -122.458721
# 0   www.tripadvisor.com/Attraction_Review-g60713-d... -122.479750
# 4   www.tripadvisor.com/Attraction_Review-g60713-d... -122.463829
# 1   www.tripadvisor.com/Attraction_Review-g60713-d... -122.448600
# 3   www.tripadvisor.com/Attraction_Review-g60713-d... -122.432600
#
#    Number of Reviews     Price Rank                Type cluster  \
# 11     2,869 reviews  No Price   23             Museums       0
# 2      3,491 reviews    $19.95    7             Museums       0
# 9      3,700 reviews  No Price   19             Museums       0
# 3      7,358 reviews  No Price   12            Shopping       0
# 5      1,591 reviews  No Price   14             Museums       0
# 6      2,036 reviews    $25.00   15             Museums       0
# 0     55,267 reviews   $105.00    1      Nature & Parks       0
# 12    19,301 reviews    $20.00   27  Sights & Landmarks       0
# 10    22,474 reviews  No Price   20  Sights & Landmarks       0
# 4     18,111 reviews  No Price   13  Sights & Landmarks       0
# 7      4,477 reviews  No Price   16  Sights & Landmarks       0
# 8      7,319 reviews  No Price   17      Nature & Parks       0
# 1      7,082 reviews  No Price    3  Sights & Landmarks       0
# 13       870 reviews  No Price   30      Nature & Parks       0
# 6      2,139 reviews    $15.00   22             Museums       1
# 2      5,953 reviews    $15.00    8             Museums       1
# 4      1,932 reviews    $15.00   18             Museums       1
# 0      9,502 reviews    $15.00    5      Nature & Parks       1
# 7      3,298 reviews  No Price   24      Nature & Parks       1
# 5        908 reviews     $9.00   21      Nature & Parks       1
# 9        635 reviews  No Price   29  Sights & Landmarks       1
# 8        941 reviews  No Price   28      Nature & Parks       1
# 3      2,822 reviews  No Price   10      Nature & Parks       1
# 1      6,378 reviews  No Price    6  Sights & Landmarks       1
# 2      2,756 reviews    $25.00    9             Museums       2
# 0     49,248 reviews  No Price    2  Sights & Landmarks       2
# 4      1,854 reviews  No Price   26      Nature & Parks       2
# 1      4,414 reviews  No Price    4    Concerts & Shows       2
# 3        974 reviews  No Price   25      Nature & Parks       2
#
#     distance_from_start  index  user_pref_flag
# 11         1.242812e+00   22.0               0
# 2          2.219988e+00    6.0               0
# 9          2.280188e+00   18.0               0
# 3          2.656803e+00   11.0               0
# 5          2.903211e+00   13.0               0
# 6          3.067366e+00   14.0               0
# 0          0.000000e+00    0.0               1
# 12         1.256720e+00   26.0               1
# 10         1.353330e+00   19.0               1
# 4          1.713420e+00   12.0               1
# 7          1.917285e+00   15.0               1
# 8          3.293127e+00   16.0               1
# 1          3.764367e+00    2.0               1
# 13         4.627095e+00   29.0               1
# 6          7.294732e-01   21.0               0
# 2          8.818229e-01    7.0               0
# 4          1.467435e+00   17.0               0
# 0          4.390790e-13    4.0               1
# 7          6.654703e-01   23.0               1
# 5          7.021737e-01   20.0               1
# 9          1.026757e+00   28.0               1
# 8          1.639878e+00   27.0               1
# 3          1.680131e+00    9.0               1
# 1          2.203012e+00    5.0               1
# 2          2.304918e+00    8.0               0
# 0          0.000000e+00    1.0               1
# 4          2.270942e+00   25.0               1
# 1          2.592252e+00    3.0               1
# 3          3.331236e+00   24.0               1
